# %% [markdown]
# # Final Activity

# %%
# We import all required libraries for our analysis
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mplb
import statsmodels.api as sm

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, root_mean_squared_error, ConfusionMatrixDisplay

# %% [markdown]
# ### Import and verify dataset

# %%
data = pd.read_csv("data/gym_churn_us.csv")
data.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# 0         3                   0.020398                           0.000000
# 1         7                   1.922936                           1.910244
# 2         2                   1.859098                           1.736502
# 3         2                   3.205633                           3.357215
# 4         3                   1.113884                           1.120078
#
#    Churn
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %% [markdown]
# aaa

# %%
# We define the predictor and target columns for our analysis
predictors_columns = ["gender", "Near_Location", "Partner", "Promo_friends", "Phone", "Contract_period", "Group_visits", "Age", "Avg_additional_charges_total", "Month_to_end_contract", "Lifetime", "Avg_class_frequency_total", "Avg_class_frequency_current_month"]
target_column = "Churn"

# We split the data into training and testing sets
predictors, target = data[predictors_columns], data[target_column]
data_train, data_test, target_train, target_test = train_test_split(predictors, target, random_state=42)

# %% [markdown]
# ## Logistic Regression Analysis

# %%
# Train a logistic regression model
linear_model = LogisticRegression(max_iter=1000)
linear_model.fit(data_train, target_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Evaluate the model on the test set
test_score = linear_model.score(data_test, target_test)
print(f"Accuracy of the LogisticRegression: {test_score:.2f}")
test_predictions = linear_model.predict(data_test)
rmse = root_mean_squared_error(y_true = target_test, y_pred = test_predictions)
print(f"Root Mean Square Error : {rmse:.2f}")
# Out:
# Accuracy of the LogisticRegression: 0.93
# Root Mean Square Error : 0.27

# %%
ConfusionMatrixDisplay.from_predictions(target_test, test_predictions, display_labels=["No Churn", "Churn"])
plt.title("Confusion Matrix for Logistic Regression Model")
plt.grid(False)
plt.show()

# %% [markdown]
# ## Decision Tree Analysis

# %%
# Train a decision tree model
tree_model = DecisionTreeClassifier(max_depth=5, random_state=42)
tree_model.fit(data_train, target_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
# Evaluate the model on the test set
test_score = tree_model.score(data_test, target_test)
print(f"Accuracy of the Decision Tree: {test_score:.2f}")
test_predictions = tree_model.predict(data_test)
rmse = root_mean_squared_error(y_true = target_test, y_pred = test_predictions)
print(f"Root Mean Square Error : {rmse:.2f}")
# Out:
# Accuracy of the Decision Tree: 0.89
# Root Mean Square Error : 0.34

# %%
ConfusionMatrixDisplay.from_predictions(target_test, test_predictions, display_labels=["No Churn", "Churn"])
plt.title("Confusion Matrix for Decision Tree Model")
plt.grid(False)
plt.show()

# %% [markdown]
# ### Display decision tree  (TBD)

# %%
# _, ax = plt.subplots(figsize=(16, 12))
# _ = plot_tree(
#     tree_model,
#     feature_names=predictors_columns,
#     class_names=["No Churn", "Churn"],  # nicer labels
#     filled=True,
#     rounded=True,
#     impurity=False,
#     ax=ax,
# )

# %% [markdown]
# ## Random Forest Analysis

# %%
# Train a random forest model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(data_train, target_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Evaluate the model on the test set
test_score = rf_model.score(data_test, target_test)
print(f"Accuracy of the Random Forest: {test_score:.2f}")
test_predictions = rf_model.predict(data_test)
rmse = root_mean_squared_error(y_true = target_test, y_pred = test_predictions)
print(f"Root Mean Square Error : {rmse:.2f}")
# Out:
# Accuracy of the Random Forest: 0.92
# Root Mean Square Error : 0.29

# %%
ConfusionMatrixDisplay.from_predictions(target_test, test_predictions, display_labels=["No Churn", "Churn"])
plt.title("Confusion Matrix for Random Forest Model")
plt.grid(False)
plt.show()
